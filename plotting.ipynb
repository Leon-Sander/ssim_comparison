# %%
from online_codes import sp_ssim
import cv2
import numpy as np
import ssim_comparison
from matplotlib import pyplot as plt

# %%
img1_path = "images/1_1.jpg"
img2_path = "images/1_2.jpg"
img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp = ssim_comparison.calculate_all_metrics_and_grayscale(img1_path, img2_path)
ssim_comparison.plt_results(img1_path,img2_path, img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp)

# %%
img1_path = "images/10_1.jpg"
img2_path = "images/10_1.jpg"
img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp = ssim_comparison.calculate_all_metrics_and_grayscale(img1_path, img2_path)
ssim_comparison.plt_results(img1_path,img2_path, img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp)

# %%
img1_path = "images/13_1.jpg"
img2_path = "images/13_2.jpg"
img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp = ssim_comparison.calculate_all_metrics_and_grayscale(img1_path, img2_path)
ssim_comparison.plt_results(img1_path,img2_path, img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp)

# %%
img1_path = "images/forest.jpg"
img2_path = "images/street.jpg"
img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp = ssim_comparison.calculate_all_metrics_and_grayscale(img1_path, img2_path)
ssim_comparison.plt_results(img1_path,img2_path, img1_grayscale, img2_grayscale ,ssim_pytorch, ms_ssim_pytorch, ssim_ski, ssim_tf, ms_ssim_tf, ms_ssim_matlab, ssim_matlab, ms_ssim_sp)
